# %%
import pandas as pd
import numpy as np
import panel as pn
pn.extension('tabulator')

import hvplot.pandas
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='a7c30951-d994-45cd-93e0-5246cbf30283'>
#   <div id="f3df313f-c1d3-4d8f-9a23-66de3884d0e0" data-root-id="a7c30951-d994-45cd-93e0-5246cbf30283" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"a55eea61-e332-49b1-9120-9aa8802e70cb":{"version":"3.4.0","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"a7c30951-d994-45cd-93e0-5246cbf30283"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"1fc61685-c055-4148-8093-c14abb4488f0","attributes":{"plot_id":"a7c30951-d994-45cd-93e0-5246cbf30283","comm_id":"db5400e95cbc487c9aa4af95e41e4861","client_comm_id":"dc72e9cd64264ea594a86eda93617f41"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","def ...
#   var render_items = [{"docid":"a55eea61-e332-49b1-9120-9aa8802e70cb","roots":{"a7c30951-d994-45cd-93e0-5246cbf30283":"f3df313f-c1d3-4d8f-9a23-66de3884d0e0"},"root_ids":["a7c30951-d994-45cd-93e0-5246cbf30283"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root.Tabulator !== undefined) && ( root.Tabulator !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
 df = pd.read_csv("https://raw.githubusercontent.com/owid/co2-data/master/owid-co2-data.csv")

# %%
if 'data' not in pn.state.cache.keys():

    df = pd.read_csv('https://raw.githubusercontent.com/owid/co2-data/master/owid-co2-data.csv')

    pn.state.cache['data'] = df.copy()

else: 

    df = pn.state.cache['data']

# %%
df
# Out:
#            country  year iso_code  population           gdp  cement_co2  \
# 0      Afghanistan  1850      AFG   3752993.0           NaN         NaN
# 1      Afghanistan  1851      AFG   3767956.0           NaN         NaN
# 2      Afghanistan  1852      AFG   3783940.0           NaN         NaN
# 3      Afghanistan  1853      AFG   3800954.0           NaN         NaN
# 4      Afghanistan  1854      AFG   3818038.0           NaN         NaN
# ...            ...   ...      ...         ...           ...         ...
# 47410     Zimbabwe  2018      ZWE  15052191.0  2.678627e+10       0.558
# 47411     Zimbabwe  2019      ZWE  15354606.0  2.514642e+10       0.473
# 47412     Zimbabwe  2020      ZWE  15669663.0  2.317871e+10       0.496
# 47413     Zimbabwe  2021      ZWE  15993525.0  2.514009e+10       0.531
# 47414     Zimbabwe  2022      ZWE  16320539.0  2.590159e+10       0.531
#
#        cement_co2_per_capita     co2  co2_growth_abs  co2_growth_prct  ...  \
# 0                        NaN     NaN             NaN              NaN  ...
# 1                        NaN     NaN             NaN              NaN  ...
# 2                        NaN     NaN             NaN              NaN  ...
# 3                        NaN     NaN             NaN              NaN  ...
# 4                        NaN     NaN             NaN              NaN  ...
# ...                      ...     ...             ...              ...  ...
# 47410                  0.037  10.715           1.419           15.265  ...
# 47411                  0.031   9.775          -0.939           -8.765  ...
# 47412                  0.032   7.850          -1.926          -19.700  ...
# 47413                  0.033   8.396           0.547            6.962  ...
# 47414                  0.033   8.856           0.460            5.477  ...
#
#        share_global_other_co2  share_of_temperature_change_from_ghg  \
# 0                         NaN                                   NaN
# 1                         NaN                                 0.157
# 2                         NaN                                 0.156
# 3                         NaN                                 0.156
# 4                         NaN                                 0.155
# ...                       ...                                   ...
# 47410                     NaN                                 0.114
# 47411                     NaN                                 0.113
# 47412                     NaN                                 0.112
# 47413                     NaN                                 0.110
# 47414                     NaN                                 0.110
#
#        temperature_change_from_ch4  temperature_change_from_co2  \
# 0                              NaN                          NaN
# 1                            0.000                        0.000
# 2                            0.000                        0.000
# 3                            0.000                        0.000
# 4                            0.000                        0.000
# ...                            ...                          ...
# 47410                        0.001                        0.001
# 47411                        0.001                        0.001
# 47412                        0.001                        0.001
# 47413                        0.001                        0.001
# 47414                        0.001                        0.001
#
#        temperature_change_from_ghg  temperature_change_from_n2o  total_ghg  \
# 0                              NaN                          NaN        NaN
# 1                            0.000                          0.0        NaN
# 2                            0.000                          0.0        NaN
# 3                            0.000                          0.0        NaN
# 4                            0.000                          0.0        NaN
# ...                            ...                          ...        ...
# 47410                        0.002                          0.0     116.76
# 47411                        0.002                          0.0     116.03
# 47412                        0.002                          0.0     113.20
# 47413                        0.002                          0.0        NaN
# 47414                        0.002                          0.0        NaN
#
#        total_ghg_excluding_lucf  trade_co2  trade_co2_share
# 0                           NaN        NaN              NaN
# 1                           NaN        NaN              NaN
# 2                           NaN        NaN              NaN
# 3                           NaN        NaN              NaN
# 4                           NaN        NaN              NaN
# ...                         ...        ...              ...
# 47410                     29.37     -0.088           -0.825
# 47411                     28.70      0.143            1.463
# 47412                     25.99      0.818           10.421
# 47413                       NaN      1.088           12.956
# 47414                       NaN        NaN              NaN
#
# [47415 rows x 79 columns]

# %%
df[df['country'] == 'North America']
# Out:
#              country  year iso_code   population  gdp  cement_co2  \
# 30956  North America  1750      NaN   11396206.0  NaN       0.000
# 30957  North America  1751      NaN          NaN  NaN       0.000
# 30958  North America  1752      NaN          NaN  NaN       0.000
# 30959  North America  1753      NaN          NaN  NaN       0.000
# 30960  North America  1754      NaN          NaN  NaN       0.000
# ...              ...   ...      ...          ...  ...         ...
# 31224  North America  2018      NaN  585864285.0  NaN      74.292
# 31225  North America  2019      NaN  590497015.0  NaN      74.841
# 31226  North America  2020      NaN  594263186.0  NaN      74.485
# 31227  North America  2021      NaN  597123384.0  NaN      78.067
# 31228  North America  2022      NaN  600323657.0  NaN      77.439
#
#        cement_co2_per_capita       co2  co2_growth_abs  co2_growth_prct  ...  \
# 30956                  0.000     0.000             NaN              NaN  ...
# 30957                    NaN     0.000           0.000              NaN  ...
# 30958                    NaN     0.000           0.000              NaN  ...
# 30959                    NaN     0.000           0.000              NaN  ...
# 30960                    NaN     0.000           0.000              NaN  ...
# ...                      ...       ...             ...              ...  ...
# 31224                  0.128  6599.176         180.933            2.819  ...
# 31225                  0.128  6489.115        -110.061           -1.668  ...
# 31226                  0.126  5835.101        -654.013          -10.079  ...
# 31227                  0.132  6201.319         366.218            6.276  ...
# 31228                  0.130  6279.689          78.370            1.264  ...
#
#        share_global_other_co2  share_of_temperature_change_from_ghg  \
# 30956                     NaN                                   NaN
# 30957                     NaN                                   NaN
# 30958                     NaN                                   NaN
# 30959                     NaN                                   NaN
# 30960                     NaN                                   NaN
# ...                       ...                                   ...
# 31224                   8.856                                22.445
# 31225                   8.787                                22.305
# 31226                   8.987                                22.163
# 31227                   8.950                                22.024
# 31228                   8.955                                21.888
#
#        temperature_change_from_ch4  temperature_change_from_co2  \
# 30956                          NaN                          NaN
# 30957                          NaN                          NaN
# 30958                          NaN                          NaN
# 30959                          NaN                          NaN
# 30960                          NaN                          NaN
# ...                            ...                          ...
# 31224                        0.052                        0.279
# 31225                        0.053                        0.282
# 31226                        0.053                        0.285
# 31227                        0.053                        0.288
# 31228                        0.053                        0.291
#
#        temperature_change_from_ghg  temperature_change_from_n2o  total_ghg  \
# 30956                          NaN                          NaN        NaN
# 30957                          NaN                          NaN        NaN
# 30958                          NaN                          NaN        NaN
# 30959                          NaN                          NaN        NaN
# 30960                          NaN                          NaN        NaN
# ...                            ...                          ...        ...
# 31224                        0.345                        0.014    7690.65
# 31225                        0.348                        0.014    7572.73
# 31226                        0.351                        0.014    6907.83
# 31227                        0.355                        0.014        NaN
# 31228                        0.358                        0.014        NaN
#
#        total_ghg_excluding_lucf  trade_co2  trade_co2_share
# 30956                       NaN        NaN              NaN
# 30957                       NaN        NaN              NaN
# 30958                       NaN        NaN              NaN
# 30959                       NaN        NaN              NaN
# 30960                       NaN        NaN              NaN
# ...                         ...        ...              ...
# 31224                   7809.65    388.745            5.891
# 31225                   7692.71    381.623            5.881
# 31226                   7023.81    434.364            7.444
# 31227                       NaN    514.813            8.302
# 31228                       NaN        NaN              NaN
#
# [273 rows x 79 columns]

# %%
df[df['country'] == 'World']
# Out:
#       country  year iso_code    population           gdp  cement_co2  \
# 46623   World  1750      NaN  7.456641e+08           NaN         NaN
# 46624   World  1751      NaN           NaN           NaN         NaN
# 46625   World  1752      NaN           NaN           NaN         NaN
# 46626   World  1753      NaN           NaN           NaN         NaN
# 46627   World  1754      NaN           NaN           NaN         NaN
# ...       ...   ...      ...           ...           ...         ...
# 46891   World  2018      NaN  7.683790e+09  1.187658e+14    1565.803
# 46892   World  2019      NaN  7.764951e+09  1.221494e+14    1615.776
# 46893   World  2020      NaN  7.840953e+09  1.185900e+14    1633.047
# 46894   World  2021      NaN  7.909295e+09  1.260048e+14    1692.404
# 46895   World  2022      NaN  7.975105e+09  1.301126e+14    1605.474
#
#        cement_co2_per_capita        co2  co2_growth_abs  co2_growth_prct  ...  \
# 46623                    NaN      9.306             NaN              NaN  ...
# 46624                    NaN      9.407           0.101            1.088  ...
# 46625                    NaN      9.505           0.098            1.041  ...
# 46626                    NaN      9.610           0.105            1.108  ...
# 46627                    NaN      9.734           0.123            1.281  ...
# ...                      ...        ...             ...              ...  ...
# 46891                  0.204  36766.945         741.491            2.058  ...
# 46892                  0.208  37040.102         273.158            0.743  ...
# 46893                  0.208  35007.738       -2032.366           -5.487  ...
# 46894                  0.214  36816.543        1808.806            5.167  ...
# 46895                  0.201  37149.785         333.242            0.905  ...
#
#        share_global_other_co2  share_of_temperature_change_from_ghg  \
# 46623                     NaN                                   NaN
# 46624                     NaN                                   NaN
# 46625                     NaN                                   NaN
# 46626                     NaN                                   NaN
# 46627                     NaN                                   NaN
# ...                       ...                                   ...
# 46891                   100.0                                 100.0
# 46892                   100.0                                 100.0
# 46893                   100.0                                 100.0
# 46894                   100.0                                 100.0
# 46895                   100.0                                 100.0
#
#        temperature_change_from_ch4  temperature_change_from_co2  \
# 46623                          NaN                          NaN
# 46624                          NaN                          NaN
# 46625                          NaN                          NaN
# 46626                          NaN                          NaN
# 46627                          NaN                          NaN
# ...                            ...                          ...
# 46891                        0.396                        1.064
# 46892                        0.401                        1.082
# 46893                        0.406                        1.100
# 46894                        0.411                        1.118
# 46895                        0.417                        1.136
#
#        temperature_change_from_ghg  temperature_change_from_n2o  total_ghg  \
# 46623                          NaN                          NaN        NaN
# 46624                          NaN                          NaN        NaN
# 46625                          NaN                          NaN        NaN
# 46626                          NaN                          NaN        NaN
# 46627                          NaN                          NaN        NaN
# ...                            ...                          ...        ...
# 46891                        1.538                        0.077  49585.910
# 46892                        1.562                        0.079  49880.602
# 46893                        1.586                        0.080  47513.148
# 46894                        1.610                        0.081        NaN
# 46895                        1.635                        0.083        NaN
#
#        total_ghg_excluding_lucf  trade_co2  trade_co2_share
# 46623                       NaN        NaN              NaN
# 46624                       NaN        NaN              NaN
# 46625                       NaN        NaN              NaN
# 46626                       NaN        NaN              NaN
# 46627                       NaN        NaN              NaN
# ...                         ...        ...              ...
# 46891                 48069.809      0.000              0.0
# 46892                 48089.621      0.000              0.0
# 46893                 46120.922      0.000              0.0
# 46894                       NaN     -0.004             -0.0
# 46895                       NaN      0.000              0.0
#
# [273 rows x 79 columns]

# %% [markdown]
# ##  Some minor data preprocessing

# %%
# Fill NAs with 0s and create GDP per capita column
df = df.fillna(0)
df['gdp_per_capita'] = np.where(df['population']!= 0, df['gdp']/ df['population'], 0)

# %%
# Make DataFrame Pipeline Interactive
idf = df.interactive()

# %% [markdown]
# ##  CO2 emission over time by continent

# %%
# Define Panel widgets
year_slider = pn.widgets.IntSlider(name='Year slider', start=1750, end=2020, step=5, value=1850)
year_slider
# Out:
# IntSlider(end=2020, name='Year slider', start=1750, step=5, value=1850)

# %%
# Radio buttons for CO2 measures
yaxis_co2 = pn.widgets.RadioButtonGroup(
    name='Y axis', 
    options=['co2', 'co2_per_capita',],
    button_type='success'
)

# %%
continents = ['World', 'Asia', 'Oceania', 'Europe', 'Africa', 'North America', 'South America', 'Antarctica']

co2_pipeline = (
    idf[
        (idf.year <= year_slider) &
        (idf.country.isin(continents))
    ]
    .groupby(['country', 'year'])[yaxis_co2].mean()
    .to_frame()
    .reset_index()
    .sort_values(by='year')  
    .reset_index(drop=True)
)

# %%
co2_pipeline
# Out:
# <div id='f861b082-fca7-4469-b7b3-5ae8eddfd920'>
#   <div id="fb93e4ff-4f22-4696-b6d6-2a1d29cea6d0" data-root-id="f861b082-fca7-4469-b7b3-5ae8eddfd920" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"4bc5219b-01b6-4071-9b48-b46ca3668eb0":{"version":"3.4.0","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"f861b082-fca7-4469-b7b3-5ae8eddfd920","attributes":{"name":"Row03743","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"ece92e1c-0205-4648-a2cd-02e3ecbe1e2e","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.2/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"bf8ba81b-6089-496c-81db-6f804ea1485d","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.2/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"3ad3daaa-e858-403b-a57e-ea64bd6933ca","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.2/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"44d2df20-b559-4f59-8ad3-55fe52eeb04e","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.2/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"3a50a1fa-130a-46b0-be53-d8b79d251909","attributes":{"name":"Column03742","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"ece92e1c-0205-4648-a2cd-02e3ecbe1e2e"},{"id":"bf8ba81b-6089-496c-81db-6f804ea1485d"},{"id":"3ad3daaa-e858-403b-a57e-ea64bd6933ca"},{"id":"44d2df20-b559-4f59-8ad3-55fe52eeb04e"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"f5967bd2-2f27-4ab4-9897-65d649fa36d9","attributes":{"name":"Column03734","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"ece92e1c-0205-4648-a2cd-02e3ecbe1e2e"},{"id":"bf8ba81b-6089-496c-81db-6f804ea1485d"},{"id":"3ad3daaa-e858-403b-a57e-ea64bd6933ca"},{"id":"44d2df20-b559-4f59-8ad3-55fe52eeb04e"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"7af278ad-78b5-49f0-bdfa-06dc69670060","attributes":{"stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"ece92e1c-0205-4648-a2cd-02e3ecbe1e2e"},{"id":"3ad3daaa-e858-403b-a57e-ea64bd6933ca"},{"id":"44d2df20-b559-4f59-8ad3-55fe52eeb04e"}],"margin":[5,10],"align":"start","title":"Year slider","start":1750,"end":2020,"value":1850,"step":5}},{"type":"object","name":"panel.models.widgets.RadioButtonGroup","id":"c66dd64f-d06b-4995-8088-874248b4fa5b","attributes":{"button_type":"success","css_classes":["solid"],"stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"ece92e1c-0205-4648-a2cd-02e3ecbe1e2e"},{"type":"object","name":"ImportedStyleSheet","id":"3966d118-7140-49a5-9766-cf0878a84ae5","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.2/dist/css/button.css"}},{"id":"3ad3daaa-e858-403b-a57e-ea64bd6933ca"},{"id":"44d2df20-b559-4f59-8ad3-55fe52eeb04e"}],"margin":[5,10],"align":"start","labels":["co2","co2_per_capita"],"active":0}}]}},{"type":"object","name":"panel.models.layout.Column","id":"92f51c5c-86e5-4ea4-b469-890f607b8b4e","attributes":{"name":"Column03739","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"ece92e1c-0205-4648-a2cd-02e3ecbe1e2e"},{"id":"bf8ba81b-6089-496c-81db-6f804ea1485d"},{"id":"3ad3daaa-e858-403b-a57e-ea64bd6933ca"},{"id":"44d2df ...

# %%
co2_plot = co2_pipeline.hvplot(x = 'year', by='country', y=yaxis_co2,line_width=2, title="CO2 emission by continent")
co2_plot
# Out:
# <div id='d689d1a3-2454-46f7-9c00-67c94f1d44cd'>
#   <div id="b7812ca7-0f6b-4a31-936e-e7210c6c56cf" data-root-id="d689d1a3-2454-46f7-9c00-67c94f1d44cd" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"61d56479-295e-43b5-8d2f-0faeb8833201":{"version":"3.4.0","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"d689d1a3-2454-46f7-9c00-67c94f1d44cd","attributes":{"name":"Row04144","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"a314a804-e4eb-46c1-b45a-d1aeddc00571","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.2/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"fececcf4-1055-4220-9619-654d299ba514","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.2/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"92182721-fb58-4409-9e5f-d98906e8fc9a","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.2/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"17abe87c-30de-434d-a443-10d3a55695b0","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.2/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"626805c2-40e6-42a7-8bd3-da5332ccfb1e","attributes":{"name":"Column04143","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"a314a804-e4eb-46c1-b45a-d1aeddc00571"},{"id":"fececcf4-1055-4220-9619-654d299ba514"},{"id":"92182721-fb58-4409-9e5f-d98906e8fc9a"},{"id":"17abe87c-30de-434d-a443-10d3a55695b0"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"edf35ff0-120c-4dda-9f39-5580fc3f1fa0","attributes":{"name":"Column04134","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"a314a804-e4eb-46c1-b45a-d1aeddc00571"},{"id":"fececcf4-1055-4220-9619-654d299ba514"},{"id":"92182721-fb58-4409-9e5f-d98906e8fc9a"},{"id":"17abe87c-30de-434d-a443-10d3a55695b0"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"4e240a17-ca09-46e7-8f5b-1cca8fb346fc","attributes":{"stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"a314a804-e4eb-46c1-b45a-d1aeddc00571"},{"id":"92182721-fb58-4409-9e5f-d98906e8fc9a"},{"id":"17abe87c-30de-434d-a443-10d3a55695b0"}],"margin":[5,10],"align":"start","title":"Year slider","start":1750,"end":2020,"value":1850,"step":5}},{"type":"object","name":"panel.models.widgets.RadioButtonGroup","id":"460b8182-7a3a-4e35-9226-57260c7d33d6","attributes":{"button_type":"success","css_classes":["solid"],"stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"a314a804-e4eb-46c1-b45a-d1aeddc00571"},{"type":"object","name":"ImportedStyleSheet","id":"a4b59119-0943-451a-a338-92277a368469","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.2/dist/css/button.css"}},{"id":"92182721-fb58-4409-9e5f-d98906e8fc9a"},{"id":"17abe87c-30de-434d-a443-10d3a55695b0"}],"margin":[5,10],"align":"start","labels":["co2","co2_per_capita"],"active":0}}]}},{"type":"object","name":"Figure","id":"95c8561e-4c33-4fc5-9748-f24d73d0e8dc","attributes":{"width":700,"height":300,"margin":[5,10],"sizing_mode":"fixed","align":"start","x_range":{"type":"object","name":"Range1d","id":"908269c0-585e-4482-b1fa-1d698f697918","attributes":{"tags":[[["year","year",null]],[]],"start":1750.0,"end":1850.0,"reset_start":1750.0,"reset_end":1850.0}},"y_range":{"type":"object","name":"Range1d","id":"dc7eb3e3-6e77-44c1-ac7c-ccd1e03d6eb3","attribute ...

# %% [markdown]
# ## (2) Table - CO2 emission over time by continent

# %%
co2_table = co2_pipeline.pipe(pn.widgets.Tabulator, pagination='remote', page_size = 10, sizing_mode='stretch_width') 
co2_table
# Out:
# <div id='5635393a-3b10-4b7c-932f-f4a9864883e8'>
#   <div id="bcc2e803-cc49-47a4-a53e-a2da49ba7b99" data-root-id="5635393a-3b10-4b7c-932f-f4a9864883e8" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"e2999574-9174-4adc-a5b1-fb0a52020cca":{"version":"3.4.0","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"5635393a-3b10-4b7c-932f-f4a9864883e8","attributes":{"name":"Row04533","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"c0c3edcf-f1b0-47b1-8d03-8fbf65dcb830","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.2/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"57444c7f-a449-49e5-a05d-10249d2aa835","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.2/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"b9f2c1e4-7563-4d56-baad-970c75e9155a","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.2/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"f7eac91b-9639-455e-9058-21918a190202","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.2/dist/bundled/theme/native.css"}}],"margin":0,"sizing_mode":"stretch_width","align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"7aa8595a-9d6c-4751-bc51-440e1ecd7593","attributes":{"name":"Column04532","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"c0c3edcf-f1b0-47b1-8d03-8fbf65dcb830"},{"id":"57444c7f-a449-49e5-a05d-10249d2aa835"},{"id":"b9f2c1e4-7563-4d56-baad-970c75e9155a"},{"id":"f7eac91b-9639-455e-9058-21918a190202"}],"margin":0,"sizing_mode":"stretch_width","align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"555465cc-0cac-4d44-89bb-d5d7ac3ff33e","attributes":{"name":"Column04526","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"c0c3edcf-f1b0-47b1-8d03-8fbf65dcb830"},{"id":"57444c7f-a449-49e5-a05d-10249d2aa835"},{"id":"b9f2c1e4-7563-4d56-baad-970c75e9155a"},{"id":"f7eac91b-9639-455e-9058-21918a190202"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"7952537f-f270-4c66-80e8-73f71adb8d27","attributes":{"stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"c0c3edcf-f1b0-47b1-8d03-8fbf65dcb830"},{"id":"b9f2c1e4-7563-4d56-baad-970c75e9155a"},{"id":"f7eac91b-9639-455e-9058-21918a190202"}],"margin":[5,10],"align":"start","title":"Year slider","start":1750,"end":2020,"value":1850,"step":5}},{"type":"object","name":"panel.models.widgets.RadioButtonGroup","id":"2aaf7a10-8e09-49aa-b2c9-8d56893c7d28","attributes":{"button_type":"success","css_classes":["solid"],"stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"c0c3edcf-f1b0-47b1-8d03-8fbf65dcb830"},{"type":"object","name":"ImportedStyleSheet","id":"5e4f40a5-31eb-4a89-ac2f-2b2215baf876","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.2/dist/css/button.css"}},{"id":"b9f2c1e4-7563-4d56-baad-970c75e9155a"},{"id":"f7eac91b-9639-455e-9058-21918a190202"}],"margin":[5,10],"align":"start","labels":["co2","co2_per_capita"],"active":0}}]}},{"type":"object","name":"panel.models.layout.Column","id":"ad1b207b-6ae5-496f-a070-072184fbc20d","attributes":{"name":"Column04531","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"c0c3edcf-f1b0-47b1-8d03-8fbf65dcb830"},{"id":"57444c7f-a449-49e5-a05d-10249d2aa835"} ...

# %% [markdown]
# ##  CO2 vs GDP scatterplot

# %%
co2_vs_gdp_scatterplot_pipeline = (
    idf[
        (idf.year == year_slider) &
        (~ (idf.country.isin(continents)))
    ]
    .groupby(['country', 'year', 'gdp_per_capita'])['co2'].mean()
    .to_frame()
    .reset_index()
    .sort_values(by='year')  
    .reset_index(drop=True)
)

# %%
co2_vs_gdp_scatterplot_pipeline
# Out:
# <div id='713ecc1d-15a1-4744-bf8d-40d4662ca0f7'>
#   <div id="f07c8ac4-fcb9-4f35-80c9-f4eb9872fe2d" data-root-id="713ecc1d-15a1-4744-bf8d-40d4662ca0f7" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"c4b55fce-890f-4287-b304-b051fdac7ed7":{"version":"3.4.0","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"713ecc1d-15a1-4744-bf8d-40d4662ca0f7","attributes":{"name":"Row07417","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"49856fba-20e6-415f-bba1-aa8b8d87a387","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.2/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"ebe7b81b-5a30-40b6-adbb-f6fc0ff06179","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.2/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"120a2183-d47d-436d-92f8-3fedee192d00","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.2/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"aec8f2d8-d6ac-40dc-99fe-787a484a0f80","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.2/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"8d712800-7599-46c3-acda-61b4bfcfe34a","attributes":{"name":"Column07416","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"49856fba-20e6-415f-bba1-aa8b8d87a387"},{"id":"ebe7b81b-5a30-40b6-adbb-f6fc0ff06179"},{"id":"120a2183-d47d-436d-92f8-3fedee192d00"},{"id":"aec8f2d8-d6ac-40dc-99fe-787a484a0f80"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"0b322a6f-8fd9-445d-835e-35697107d3d0","attributes":{"name":"Column07408","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"49856fba-20e6-415f-bba1-aa8b8d87a387"},{"id":"ebe7b81b-5a30-40b6-adbb-f6fc0ff06179"},{"id":"120a2183-d47d-436d-92f8-3fedee192d00"},{"id":"aec8f2d8-d6ac-40dc-99fe-787a484a0f80"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"ef43966c-1e42-4857-a5f9-0a8aaff96d27","attributes":{"stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"49856fba-20e6-415f-bba1-aa8b8d87a387"},{"id":"120a2183-d47d-436d-92f8-3fedee192d00"},{"id":"aec8f2d8-d6ac-40dc-99fe-787a484a0f80"}],"margin":[5,10],"align":"start","title":"Year slider","start":1750,"end":2020,"value":1850,"step":5}}]}},{"type":"object","name":"panel.models.layout.Column","id":"bf173981-4e58-482a-a800-b83735cf50e4","attributes":{"name":"Column07413","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"49856fba-20e6-415f-bba1-aa8b8d87a387"},{"id":"ebe7b81b-5a30-40b6-adbb-f6fc0ff06179"},{"id":"120a2183-d47d-436d-92f8-3fedee192d00"},{"id":"aec8f2d8-d6ac-40dc-99fe-787a484a0f80"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.markup.HTML","id":"3a30e1a0-ff3e-4f84-9720-e2dbc291df98","attributes":{"stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"49856fba-20e6-415f-bba1-aa8b8d87a387"},{"type":"object","name":"ImportedStyleSheet","id":"c0ae3aee-3b1e-446a-8af3-c6acb6b82d4c","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.2/dist/css/dataframe.css"}},{"id":"120a2183-d47d-436d-92f8-3fedee192d00"},{"id":"aec8f2d8-d6ac-40dc-99fe-787a484a0f80"}],"margin":[5,10],"align":"start","text":"&lt;table class=&quot;da ...

# %%
co2_vs_gdp_scatterplot = co2_vs_gdp_scatterplot_pipeline.hvplot(x='gdp_per_capita', 
                                                                y='co2', 
                                                                by='country', 
                                                                size=80, kind="scatter", 
                                                                alpha=0.7,
                                                                legend=False, 
                                                                height=500, 
                                                                width=500)
co2_vs_gdp_scatterplot
# Out:
# <div id='a95ca40c-6876-49e2-ad27-b67a2446b768'>
#   <div id="dec17602-7cba-474a-90e1-c5583edb5f70" data-root-id="a95ca40c-6876-49e2-ad27-b67a2446b768" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"9102b533-c0ed-477f-a75d-dec297647bf7":{"version":"3.4.0","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"a95ca40c-6876-49e2-ad27-b67a2446b768","attributes":{"name":"Row11846","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"0bbffcfc-c230-4b3a-b622-d783e18d38b1","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.2/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"5f2db70f-ba48-40c1-84f1-7512eac59b23","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.2/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"1e9d288a-b204-48e7-aee7-eddfe0ddb434","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.2/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"32cd963b-a166-4376-98f0-ad0e03ea4861","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.2/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"bd961df6-f20e-48ce-8f66-d65e901b8b72","attributes":{"name":"Column11845","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"0bbffcfc-c230-4b3a-b622-d783e18d38b1"},{"id":"5f2db70f-ba48-40c1-84f1-7512eac59b23"},{"id":"1e9d288a-b204-48e7-aee7-eddfe0ddb434"},{"id":"32cd963b-a166-4376-98f0-ad0e03ea4861"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"23ae162b-c974-483b-beef-5799d64468a8","attributes":{"name":"Column11836","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"0bbffcfc-c230-4b3a-b622-d783e18d38b1"},{"id":"5f2db70f-ba48-40c1-84f1-7512eac59b23"},{"id":"1e9d288a-b204-48e7-aee7-eddfe0ddb434"},{"id":"32cd963b-a166-4376-98f0-ad0e03ea4861"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"181f86c7-c3f6-4679-b862-6db676af1911","attributes":{"stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"0bbffcfc-c230-4b3a-b622-d783e18d38b1"},{"id":"1e9d288a-b204-48e7-aee7-eddfe0ddb434"},{"id":"32cd963b-a166-4376-98f0-ad0e03ea4861"}],"margin":[5,10],"align":"start","title":"Year slider","start":1750,"end":2020,"value":1850,"step":5}}]}},{"type":"object","name":"Figure","id":"9d2955c3-089c-47e8-ba4d-9a83109bfb9d","attributes":{"width":500,"height":500,"margin":[5,10],"sizing_mode":"fixed","align":"start","x_range":{"type":"object","name":"Range1d","id":"b4b26391-5777-4f2f-a16e-c877754259c9","attributes":{"tags":[[["gdp_per_capita","gdp_per_capita",null]],[]],"start":-432.03170188910445,"end":4752.348720780149,"reset_start":-432.03170188910445,"reset_end":4752.348720780149}},"y_range":{"type":"object","name":"Range1d","id":"0d1e46f1-5380-4547-b243-e49a5b96711b","attributes":{"tags":[[["co2","co2",null]],{"type":"map","entries":[["invert_yaxis",false],["autorange",false]]}],"start":-19.6643,"end":216.3073,"reset_start":-19.6643,"reset_end":216.3073}},"x_scale":{"type":"object","name":"LinearScale","id":"632afd06-0ba3-41cf-bca7-7ff30ec81349"},"y_scale":{"type":"object","name":"LinearScale","id":"65acded4-c98b-4a78-864c-e95ec181879c"},"title":{"type":"object","name":"Title","id":"b26f2cb2-7426-474c-88e4-dc5eede736a5","attributes":{"text_color":"black","text_font_size":"12pt"}},"renderers":[{"type":"object","name":"GlyphRenderer","id":"16b30053-fa6f-4358-bfc5-818ed6d65676","attributes":{"data_source":{"type":"object","name":"ColumnDataSource", ...

# %% [markdown]
# ##  Bar chart with CO2 sources by continent

# %%
yaxis_co2_source = pn.widgets.RadioButtonGroup(
    name='Y axis', 
    options=['coal_co2', 'oil_co2', 'gas_co2'], 
    button_type='success'
)

continents_excl_world = ['Asia', 'Oceania', 'Europe', 'Africa', 'North America', 'South America', 'Antarctica']

co2_source_bar_pipeline = (
    idf[
        (idf.year == year_slider) &
        (idf.country.isin(continents_excl_world))
    ]
    .groupby(['year', 'country'])[yaxis_co2_source].sum()
    .to_frame()
    .reset_index()
    .sort_values(by='year')  
    .reset_index(drop=True)
)

# %%
co2_source_bar_plot = co2_source_bar_pipeline.hvplot(kind='bar', 
                                                     x='country', 
                                                     y=yaxis_co2_source, 
                                                     title='CO2 source by continent')
co2_source_bar_plot
# Out:
# <div id='659ae984-80b2-483f-8719-b5a8a6f91d84'>
#   <div id="a24bdc51-cfc4-4168-8f6a-c3d29dfd775d" data-root-id="659ae984-80b2-483f-8719-b5a8a6f91d84" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"aac4d46b-8357-48a0-8fc4-077bad33511d":{"version":"3.4.0","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"659ae984-80b2-483f-8719-b5a8a6f91d84","attributes":{"name":"Row17684","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"672c880d-b6d0-4863-b685-c0f219859b2b","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.2/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"6c7b165e-9026-4e27-8e7e-53d15d20cd54","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.2/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"8308ca8a-8003-4784-b5f4-4d1e99eb8d2b","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.2/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"3424ba44-8ceb-4b4b-bc13-f18cbcc32de8","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.2/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"9def294b-967c-46e3-ab53-b6c5945bc75d","attributes":{"name":"Column17683","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"672c880d-b6d0-4863-b685-c0f219859b2b"},{"id":"6c7b165e-9026-4e27-8e7e-53d15d20cd54"},{"id":"8308ca8a-8003-4784-b5f4-4d1e99eb8d2b"},{"id":"3424ba44-8ceb-4b4b-bc13-f18cbcc32de8"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"78f2df83-0446-472a-a4dc-856b59ad6d82","attributes":{"name":"Column17674","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"672c880d-b6d0-4863-b685-c0f219859b2b"},{"id":"6c7b165e-9026-4e27-8e7e-53d15d20cd54"},{"id":"8308ca8a-8003-4784-b5f4-4d1e99eb8d2b"},{"id":"3424ba44-8ceb-4b4b-bc13-f18cbcc32de8"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"ef145da3-38de-4717-b0aa-41ac3634f431","attributes":{"stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"672c880d-b6d0-4863-b685-c0f219859b2b"},{"id":"8308ca8a-8003-4784-b5f4-4d1e99eb8d2b"},{"id":"3424ba44-8ceb-4b4b-bc13-f18cbcc32de8"}],"margin":[5,10],"align":"start","title":"Year slider","start":1750,"end":2020,"value":1850,"step":5}},{"type":"object","name":"panel.models.widgets.RadioButtonGroup","id":"1c474f56-494b-4863-821d-95f19c3284a8","attributes":{"button_type":"success","css_classes":["solid"],"stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"672c880d-b6d0-4863-b685-c0f219859b2b"},{"type":"object","name":"ImportedStyleSheet","id":"c7e5775a-8392-42a1-87f7-fc375133be6e","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.2/dist/css/button.css"}},{"id":"8308ca8a-8003-4784-b5f4-4d1e99eb8d2b"},{"id":"3424ba44-8ceb-4b4b-bc13-f18cbcc32de8"}],"margin":[5,10],"align":"start","labels":["coal_co2","oil_co2","gas_co2"],"active":0}}]}},{"type":"object","name":"Figure","id":"25b8fd64-19b0-4dda-9f8f-ae760f590688","attributes":{"width":700,"height":300,"margin":[5,10],"sizing_mode":"fixed","align":"start","x_range":{"type":"object","name":"FactorRange","id":"7d84ff98-b03c-4bcc-b0e5-7ca534059a16","attributes":{"tags":[[["country","country",null]],[]],"factors":["Africa","Asia","Europe","North America","Oceania","South America"]}},"y_range":{"type":"object","name":"Range1d","id":"a63533c0-5fb5-4396- ...

# %% [markdown]
# ## Creating Dashboard

# %%
template = pn.template.FastListTemplate(
    title='World CO2 emission dashboard', 
    sidebar=[pn.pane.Markdown("# CO2 Emissions and Climate Change"), 
             pn.pane.Markdown("#### Carbon dioxide emissions are the primary driver of global climate change. It’s widely recognised that to avoid the worst impacts of climate change, the world needs to urgently reduce emissions. But, how this responsibility is shared between regions, countries, and individuals has been an endless point of contention in international discussions."), 
             pn.pane.PNG('climate_day.png', sizing_mode='scale_both'),
             pn.pane.Markdown("## Settings"),   
             year_slider],
    main=[pn.Row(pn.Column(yaxis_co2, 
                           co2_plot.panel(width=700), margin=(0,25)), 
                 co2_table.panel(width=500)), 
          pn.Row(pn.Column(co2_vs_gdp_scatterplot.panel(width=600), margin=(0,25)), 
                 pn.Column(yaxis_co2_source, co2_source_bar_plot.panel(width=600)))],
    accent_base_color="#88d8b0",
    header_background="#88d8b0",
)

template.servable();
